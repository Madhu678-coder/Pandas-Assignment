# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhu678-coder/Pandas-Assignment/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Ch.MadhuKumar")
# Out:
# Ch.MadhuKumar

# %% [markdown]
# Importing libraries

# %%
import pandas as pd

# %% [markdown]
# Reading the csv file

# %%
df=pd.read_csv("/content/oecd_bli_2015.csv")

# %% [markdown]
# print the first 5 rows in the dataset

# %%
df.head()
# Out:
#   LOCATION         Country INDICATOR                           Indicator  \
# 0      AUS       Australia   HO_BASE  Dwellings without basic facilities
# 1      AUT         Austria   HO_BASE  Dwellings without basic facilities
# 2      BEL         Belgium   HO_BASE  Dwellings without basic facilities
# 3      CAN          Canada   HO_BASE  Dwellings without basic facilities
# 4      CZE  Czech Republic   HO_BASE  Dwellings without basic facilities
#
#   MEASURE Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0       L   Value        TOT      Total        PC  Percentage               0
# 1       L   Value        TOT      Total        PC  Percentage               0
# 2       L   Value        TOT      Total        PC  Percentage               0
# 3       L   Value        TOT      Total        PC  Percentage               0
# 4       L   Value        TOT      Total        PC  Percentage               0
#
# ...

# %% [markdown]
#     Find missing values in a DataFrame and count them column-wise.

# %%
df.isnull().sum()
# Out:
# LOCATION                    0
# Country                     0
# INDICATOR                   0
# Indicator                   0
# MEASURE                     0
# Measure                     0
# INEQUALITY                  0
# Inequality                  0
# Unit Code                   0
# Unit                        0
# PowerCode Code              0
# PowerCode                   0
# Reference Period Code    3292
# Reference Period         3292
# Value                       0
# Flag Codes               2172
# Flags                    2172
# dtype: int64

# %% [markdown]
#     Filter rows in a DataFrame where a column value > 100.

# %%
filter_df=df[df['Value']>100]
filter_df
# Out:
#      LOCATION         Country INDICATOR  \
# 327       AUS       Australia   IW_HADI
# 328       AUT         Austria   IW_HADI
# 329       BEL         Belgium   IW_HADI
# 330       CAN          Canada   IW_HADI
# 331       CZE  Czech Republic   IW_HADI
# ...       ...             ...       ...
# 1743      EST         Estonia   ES_STCS
# 1744      ISR          Israel   ES_STCS
# 1745      RUS          Russia   ES_STCS
# 1746      SVN        Slovenia   ES_STCS
# 1747     OECD    OECD - Total   ES_STCS
#
#                                      Indicator MEASURE Measure INEQUALITY  \
# 327   Household net adjusted disposable income       L   Value        TOT
# 328   Household net adjusted disposable income       L   Value        TOT
# 329   Household net adjusted disposable income       L   Value        TOT
# 330   Household net adjusted disposable income       L   Value        TOT
# 331   Household net adjusted disposable income       L   Value        TOT
# ...

# %% [markdown]
# Group a DataFrame by a column and calculate the mean of each group.

# %%
group_by=df.groupby('Indicator')['Value'].mean()
group_by
# Out:
# Indicator
# Air pollution                                   19.889908
# Assault rate                                     4.056757
# Consultation on rule-making                      7.071560
# Dwellings without basic facilities               2.532110
# Educational attainment                          75.369369
# Employees working very long hours                9.021441
# Employment rate                                 64.994595
# Homicide rate                                    2.928829
# Household net adjusted disposable income     25879.322404
# Household net financial wealth               40519.394495
# Housing expenditure                             20.807339
# Job security                                     5.688288
# Life expectancy                                 79.714414
# Life satisfaction                                6.553631
# Long-term unemployment rate                      3.760734
# Personal earnings                            34489.572973
# ...

# %% [markdown]
#     Sorted a DataFrame by Country and value columns.

# %%
sorted=df.sort_values(by=['Country','Value'],ascending=[True,False])
sorted
# Out:
#      LOCATION        Country INDICATOR  \
# 1211      AUS      Australia  JE_PEARN
# 436       AUS      Australia   IW_HADI
# 1137      AUS      Australia  JE_PEARN
# 1100      AUS      Australia  JE_PEARN
# 510       AUS      Australia   IW_HNFW
# ...       ...            ...       ...
# 2951      USA  United States   PS_SFRV
# 1055      USA  United States   JE_LTUR
# 29        USA  United States   HO_BASE
# 66        USA  United States   HO_BASE
# 102       USA  United States   HO_BASE
#
#                                      Indicator MEASURE Measure INEQUALITY  \
# 1211                         Personal earnings       L   Value        HGH
# 436   Household net adjusted disposable income       L   Value        HGH
# 1137                         Personal earnings       L   Value         MN
# 1100                         Personal earnings       L   Value        TOT
# 510             Household net financial wealth       L   Value        TOT
# ...

# %% [markdown]
# Add a new column(Total) to a DataFrame that is a transformation of existing columns.by adding the value column twice

# %%
df['Total']=df['Value']+df['Value']

# %%
print(df['Total'])
# Out:
# 0        2.20
# 1        2.00
# 2        4.00
# 3        0.40
# 4        1.80
#         ...
# 3287    28.86
# 3288    28.48
# 3289    29.50
# 3290    28.24
# 3291    29.48
# Name: Total, Length: 3292, dtype: float64

# %%
df.head()
# Out:
#   LOCATION         Country INDICATOR                           Indicator  \
# 0      AUS       Australia   HO_BASE  Dwellings without basic facilities
# 1      AUT         Austria   HO_BASE  Dwellings without basic facilities
# 2      BEL         Belgium   HO_BASE  Dwellings without basic facilities
# 3      CAN          Canada   HO_BASE  Dwellings without basic facilities
# 4      CZE  Czech Republic   HO_BASE  Dwellings without basic facilities
#
#   MEASURE Measure INEQUALITY Inequality Unit Code        Unit  PowerCode Code  \
# 0       L   Value        TOT      Total        PC  Percentage               0
# 1       L   Value        TOT      Total        PC  Percentage               0
# 2       L   Value        TOT      Total        PC  Percentage               0
# 3       L   Value        TOT      Total        PC  Percentage               0
# 4       L   Value        TOT      Total        PC  Percentage               0
#
# ...

# %% [markdown]
# Loading the second dataset

# %%
df1=pd.read_csv(r"/content/gdp_per_capita.csv",encoding='latin-1')

# %% [markdown]
#    Merge two DataFrames on a common column (inner join).

# %%
merge=pd.merge(df,df1,on='Country',how='inner')
merge
# Out:
#      LOCATION         Country INDICATOR  \
# 0         AUS       Australia   HO_BASE
# 1         AUT         Austria   HO_BASE
# 2         BEL         Belgium   HO_BASE
# 3         CAN          Canada   HO_BASE
# 4         CZE  Czech Republic   HO_BASE
# ...       ...             ...       ...
# 3213      CHL           Chile   WL_TNOW
# 3214      EST         Estonia   WL_TNOW
# 3215      ISR          Israel   WL_TNOW
# 3216      RUS          Russia   WL_TNOW
# 3217      SVN        Slovenia   WL_TNOW
#
#                                       Indicator MEASURE Measure INEQUALITY  \
# 0            Dwellings without basic facilities       L   Value        TOT
# 1            Dwellings without basic facilities       L   Value        TOT
# 2            Dwellings without basic facilities       L   Value        TOT
# 3            Dwellings without basic facilities       L   Value        TOT
# 4            Dwellings without basic facilities       L   Value        TOT
# ...
